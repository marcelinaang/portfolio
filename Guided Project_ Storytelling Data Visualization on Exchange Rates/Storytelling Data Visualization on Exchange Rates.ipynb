# %% [markdown]
# # Storytelling Data Visualization on Exchange Rates
# ## Introduction
# The dataset we'll use describes Euro daily exchange rates between 1999 and 2021. The euro (symbolized with €) is the official currency in most of the countries of the European Union.
#
# If the exchange rate of the euro to the US dollar is 1.5, you get 1.5 US dollars if you pay 1.0 euro (one euro has more value than one US dollar at this exchange rate).
#
# Daria Chemkaeva put together the data set and made it available on [Kaggle](https://www.kaggle.com/lsind18/euro-exchange-daily-rates-19992020) — the data source is the European Central Bank. Note that the dataset gets regular updates — we downloaded it on January 2021.

# %%
import pandas as pd

exchange_rates = pd.read_csv('euro-daily-hist_1999_2020.csv')
exchange_rates.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2021-01-08               1.5758           1.9558            6.5748
# 1   2021-01-07               1.5836           1.9558            6.5172
# 2   2021-01-06               1.5824           1.9558            6.5119
# 3   2021-01-05               1.5927           1.9558            6.5517
# 4   2021-01-04               1.5928           1.9558            6.3241
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.5543         1.0827                   7.9184              NaN
# 1             1.5601         1.0833                   7.9392              NaN
# 2             1.5640         1.0821                   7.9653              NaN
# 3             1.5651         1.0803                   7.9315              NaN
# 4             1.5621         1.0811                   7.9484              NaN
#
# ...

# %%
exchange_rates.tail()
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 5694   1999-01-08               1.8406              NaN               NaN
# 5695   1999-01-07               1.8474              NaN               NaN
# 5696   1999-01-06               1.8820              NaN               NaN
# 5697   1999-01-05               1.8944              NaN               NaN
# 5698   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 5694             1.7643         1.6138                      NaN
# 5695             1.7602         1.6165                      NaN
# 5696             1.7711         1.6116                      NaN
# 5697             1.7965         1.6123                      NaN
# 5698             1.8004         1.6168                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]  ... [Romanian leu ]  \
# ...

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5699 entries, 0 to 5698
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              5699 non-null   object
#  1   [Australian dollar ]      5699 non-null   object
#  2   [Bulgarian lev ]          5297 non-null   object
#  3   [Brazilian real ]         5431 non-null   object
#  4   [Canadian dollar ]        5699 non-null   object
#  5   [Swiss franc ]            5699 non-null   object
#  6   [Chinese yuan renminbi ]  5431 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           5699 non-null   object
#  9   [Danish krone ]           5699 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      5699 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %% [markdown]
# Based on our initial inspection, we can see that our dataset consists of 41 columns and 5,699 rows. We can also see that some of our data are missing. As for the datatype, most of our columns are considered as string. Only Iceland Krona, Romanian Leu, and Turkish Lira are considered as numeric data.
#
# ## Data Cleaning
# Our focus in this project will be on the exchange rate between the Euro and the American Dollar. We'll do the following steps first:
# - We rename the `[US dollar ]` and `Period\Unit`: columns to something easier to type — `US_dollar` and `Time`.
# - We change the `Time` column to a `datetime` data type.
# - We sort the values by `Time` in ascending order.
# - We reset the index (and drop the initial index).

# %%
exchange_rates.rename(columns={'[US dollar ]': 'US_dollar',
                               'Period\\Unit:': 'Time'},
                      inplace=True)
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])
exchange_rates.sort_values('Time', inplace=True)
exchange_rates.reset_index(drop=True, inplace=True)
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5699 entries, 0 to 5698
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Time                      5699 non-null   datetime64[ns]
#  1   [Australian dollar ]      5699 non-null   object
#  2   [Bulgarian lev ]          5297 non-null   object
#  3   [Brazilian real ]         5431 non-null   object
#  4   [Canadian dollar ]        5699 non-null   object
#  5   [Swiss franc ]            5699 non-null   object
#  6   [Chinese yuan renminbi ]  5431 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           5699 non-null   object
#  9   [Danish krone ]           5699 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      5699 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %% [markdown]
# Next, we'll continue our cleaning process. To do so, we'll isolate the `Time` and `US_dollar` columns.

# %%
euro_to_dollar = exchange_rates[['Time', 'US_dollar']].copy()
euro_to_dollar['US_dollar'].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1305     7
# 1.1193     6
#           ..
# 0.9779     1
# 1.3735     1
# 0.9264     1
# 0.9905     1
# 1.4903     1
# Name: US_dollar, Length: 3528, dtype: int64

# %% [markdown]
# When we run the `Series.value_counts()` method on the `US_dollar` column, we can see that there are 62 values of '-'. This particular value is not useful. so, we'll drop the rows with '-' value in `US_dollar` column.

# %%
euro_to_dollar = euro_to_dollar[euro_to_dollar['US_dollar'] != '-']
euro_to_dollar.shape
# Out:
# (5637, 2)

# %% [markdown]
# Now we have 5,637 rows left. Next, we'll convert the `US_dollar` column from string to float data type.

# %%
euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype('float')
euro_to_dollar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5637 entries, 0 to 5698
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       5637 non-null   datetime64[ns]
#  1   US_dollar  5637 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 132.1 KB

# %% [markdown]
# ## Rolling Mean
# Now that we're finished cleaning the data, we'll generate a line plot to visualize the evolution of the euro-dollar exchange rate.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'])
plt.show()

# %% [markdown]
# If we look at the line's shape, we see many small wiggles — rather than seeing a smooth line. The wiggles, however, have meaning: they are the visual representation of the daily variation in the exchange rate. The rate goes up and down, up and down again, day to day. The rate only shows clear upward or downward trends in the longer run (months or years).
#
# We don't want to show that daily variation on our graph. Instead, we want to hide it and show only the long-term trends. So, we will calculate the rolling mean (also known as the moving average) using `pandas.Series.rolling().mean()` method.

# %%
euro_to_dollar['rolling_mean'] = euro_to_dollar['US_dollar'].rolling(30).mean()

plt.plot(euro_to_dollar['Time'], euro_to_dollar['rolling_mean'])
plt.show()

# %% [markdown]
# We can see that our plot becomes smoother when we use the rolling mean.
#
# ## Coming Up with an Idea
# Our goal is to create a storytelling data visualization using the data we have. Here are a few story ideas for our data:
# - We show how the euro-dollar rate has changed during the coronavirus pandemic. We can show the 2020 data and the 2016-2019 data as a baseline. We can use a line plot.
# - We show how the euro-dollar rate changed during the 2007-2008 financial crisis. We can also show the data for 2006 and 2009 for comparison. We can use a line plot.
# - We show comparatively how the euro-dollar rate changed under the last three US presidents (George W. Bush (2001-2009), Barack Obama (2009-2017), and Donald Trump (2017-2021)). We can use a line plot.
#
# Now that we have some ideas on what story we want to tell, we're going to think more about how the graph is going to look.
#
# First, we need to choose the right graph type. The graph should give our story the visual form it needs — we don't want to choose a histogram to visually represent a time series. Equally important, we need to choose something that our audience will be familiar with. Both things considered,  we'll use line graph.
#
# ## Visualization of Ideas
# ### The Coronavirus Pandemic

# %%
# Get data during pandemic and 5 years before pandemic for comparison
pandemic = euro_to_dollar[euro_to_dollar['Time'] > '2020-01-13'].copy()
before_pandemic = euro_to_dollar[euro_to_dollar['Time'].between('2015-01-13', '2020-01-13')].copy()

# Create plot with style
style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(8,3))
ax.grid(alpha=0.5)
ax.plot(before_pandemic['Time'], before_pandemic['rolling_mean'], 
        color='#A6D785', linewidth=1.25)
ax.plot(pandemic['Time'], pandemic['rolling_mean'], 
        color='red', linewidth=2.5)

plt.show()

# %% [markdown]
# ### The Financial Crisis

# %%
# Import style
import matplotlib.style as style

# Get data during 2007-2008 financial crisis and 2006-2009 for comparison
euro_to_dollar_7_8 = euro_to_dollar[euro_to_dollar['Time'].dt.year.between(2007, 2008)].copy()
euro_to_dollar_6_9 = euro_to_dollar[euro_to_dollar['Time'].dt.year.between(2006, 2009)].copy()

# Create plot with style
style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(8,3))
ax.grid(alpha=0.5)
ax.plot(euro_to_dollar_6_9['Time'], euro_to_dollar_6_9['rolling_mean'], 
        color='#A6D785', linewidth=1.25)
ax.plot(euro_to_dollar_7_8['Time'], euro_to_dollar_7_8['rolling_mean'], 
        color='red', linewidth=2.5)

# Highlighting the peak of the crisis
ax.axvspan(xmin=733112.0, xmax=733302.0, ymin=0.085,
           alpha=0.3, color='grey')

# Customize ticks
ax.set_xticklabels(['2006', '', '2007', '', '2008', '', '2009', '', '2010'], alpha=0.5)
ax.set_yticklabels(['1.1', '1.2', '1.3', '1.4', '1.5', '1.6'], alpha=0.5)

# Add title & subtitle
ax.text(732142, 1.66, "Euro-USD rate peaked at 1.59 during 2007-2008's financial crisis",
       weight='bold', size=14.5)
ax.text(732142, 1.62, "Euro-USD exchange rates between 2006 and 2010", size=12.5)

# Add footer
ax.text(732142, 1.07, '©DATAQUEST' + ' '*99 + 'Source: European Central Bank',
        color = '#f0f0f0', backgroundcolor = '#4d4d4d',
        size=10)

plt.show()

# %% [markdown]
# ### The Three Presidents

# %%
import matplotlib.dates as mdates

# Get data by president
bush = euro_to_dollar[euro_to_dollar['Time'].between('2001-01-20', '2009-01-20', inclusive='left')].copy()
obama = euro_to_dollar[euro_to_dollar['Time'].between('2009-01-20', '2017-01-20', inclusive='left')].copy()
trump = euro_to_dollar[euro_to_dollar['Time'].between('2017-01-20', '2021-01-20', inclusive='left')].copy()

# Adding the subplots
style.use('fivethirtyeight')
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(2,3,1)
ax2 = plt.subplot(2,3,2)
ax3 = plt.subplot(2,3,3)
ax4 = plt.subplot(2,1,2)
axes = [ax1, ax2, ax3, ax4]

# Changes to all the subplots
for ax in axes:
    ax.set_ylim(0.8, 1.7)
    ax.set_yticks([1.0, 1.2, 1.4, 1.6])
    ax.set_yticklabels(['1.0', '1.2', '1.4', '1.6'], alpha=0.5)
    ax.grid(alpha=0.5)   
    
# Create bush plot
ax1.plot(bush['Time'], bush['rolling_mean'], color='#BF5FFF', linewidth=2.5)
ax1.set_xticklabels(['', '2001','', '2003', '', '2005', '', '2007', '', '2009'], alpha=0.5)

# Create obama plot
ax2.plot(obama['Time'], obama['rolling_mean'], color='#ffa500', linewidth=2.5)
ax2.set_xticklabels(['', '2009','', '2011', '', '2013', '', '2015', '', '2017'], alpha=0.5)

# Create trump plot
ax3.plot(trump['Time'], trump['rolling_mean'], color='#00B2EE', linewidth=2.5)
ax3.set_xticklabels(['2017','', '2018','', '2019','', '2020', '', '2021', ''], alpha=0.5)

# Create bush-obama-trump plot
ax4.plot(bush['Time'], bush['rolling_mean'], color='#BF5FFF', linewidth=2.5)
ax4.plot(obama['Time'], obama['rolling_mean'], color='#ffa500', linewidth=2.5)
ax4.plot(trump['Time'], trump['rolling_mean'], color='#00B2EE', linewidth=2.5)
ax4.xaxis.set_major_locator(mdates.YearLocator(base=1))
years = []
for year in range(2000, 2023):
    if year % 4 != 1:
        years.append('')
    else:
        years.append(str(year))
ax4.set_xticklabels(years, alpha=0.5)

# Add title & subtitles
ax1.text(729800, 2.3, "Euro-USD rate averaged 1.22 under the last three US presidents",
       weight='bold', size=20)
ax1.text(729800, 2.1, """Euro-USD exchange rates under George W. Bush (2001-2009), Barack Obama (2009-2017), and
Donald Trump (2017-2021)""", size=16)
ax1.text(731550, 1.9, 'BUSH', weight='bold', size=16, color='#BF5FFF')
ax1.text(731250, 1.8, '(2001-2009)', size=14, weight='bold', alpha=0.3)
ax2.text(734400, 1.9, 'OBAMA', weight='bold', size=16, color='#ffa500')
ax2.text(734200, 1.8, '(2009-2017)', size=14, weight='bold', alpha=0.3)
ax3.text(736800, 1.9, 'TRUMP', weight='bold', size=16, color='#00B2EE')
ax3.text(736710, 1.8, '(2017-2021)', size=14, weight='bold', alpha=0.3)

# Add footer
ax4.text(729800, 0.6, '©DATAQUEST' + ' '*177 + 'Source: European Central Bank',
        color = '#f0f0f0', backgroundcolor = '#4d4d4d',
        size=10)

plt.show()
